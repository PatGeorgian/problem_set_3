# %%
# Import libraries
import matplotlib.pyplot as plt

# Create data (replace with your data if you have real data)
years = [1867, 1870, 1875, 1880, 1885, 1890, 1895, 1900, 1905, 1910, 1915, 1920, 1925, 1930, 1935, 1940, 1945, 1950, 1955, 1960, 1965, 1970, 1975, 1980, 1985, 1990, 1995, 2000, 2005, 2010, 2014]
marriages_per_capita = [0.085, 0.090, 0.095, 0.100, 0.105, 0.110, 0.115, 0.120, 0.125, 0.130, 0.125, 0.140, 0.135, 0.130, 0.120, 0.125, 0.150, 0.140, 0.135, 0.130, 0.125, 0.120, 0.110, 0.105, 0.100, 0.095, 0.090, 0.085, 0.080, 0.075, 0.070]
divorces_per_capita = [0.020, 0.022, 0.025, 0.030, 0.035, 0.040, 0.045, 0.050, 0.055, 0.060, 0.065, 0.070, 0.075, 0.080, 0.085, 0.090, 0.095, 0.100, 0.110, 0.120, 0.135, 0.150, 0.160, 0.170, 0.165, 0.160, 0.155, 0.150, 0.145, 0.140, 0.135]

# Create the line plot
plt.figure(figsize=(10, 6))  # Set the figure size

# Plot marriages per capita
plt.plot(years, marriages_per_capita, label='Marriages per Capita')

# Plot divorces per capita
plt.plot(years, divorces_per_capita, label='Divorces per Capita')

# Set labels and title
plt.xlabel('Year')
plt.ylabel('Marriages/Divorces per Capita')
plt.title('Marriages and Divorces per Capita in the U.S. (1867-2014)')

# Add legend
plt.legend()

# Show the plot
plt.grid(True)
plt.tight_layout()
plt.show()
